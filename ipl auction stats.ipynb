# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
url="https://www.iplt20.com/auction/2022"
r=requests.get(url)
print(r)
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(r.text,"lxml")
table=soup.find("table",class_="ih-td-tab auction-tbl")
print(table)
# Out:
# <table class="ih-td-tab auction-tbl" width="100%">
# <tr class="ih-pt-tbl" style="display:revert">
# <th class="skip-filter" style="width:25%;text-align: left;">TEAM</th>
# <th class="skip-filter" style="width:25%;">FUNDS REMAINING</th>
# <th class="skip-filter" style="width:25%;">OVERSEAS PLAYERS </th>
# <th class="skip-filter" style="width:25%;">TOTAL PLAYERS</th>
# </tr>
# <tbody id="pointsdata">
# <tr>
# <td class="ih-t-color">
# <div class="ih-pt-ic">
# <div class="ih-pt-img" style="width: 60px">
# <img alt="" src="https://bcciplayerimages.s3.ap-south-1.amazonaws.com/ipl/franchises/1644311961_CSKroundbig.png"/>
# </div>
# <h2 class="ih-pt-cont">Chennai Super Kings</h2>
# </div>
# </td>
# <td>₹2,95,00,000</td>
# <td>8</td>
# <td>25</td>
# </tr>
# <tr>
# <td class="ih-t-color">
# <div class="ih-pt-ic">
# <div class="ih-pt-img" style="width: 60px">
# <img alt="" src="https://bcciplayerimages.s3.ap-south-1.amazonaws.com/ipl/franchises/1644312373_DCroundbig.png"/>
# </div>
# <h2 class="ih-pt-cont">Delhi Capitals</h2>
# </div>
# </td>
# <td>₹10,00,000</td>
# <td>7</td>
# <td>24</td>
# </tr>
# <tr>
# <td class="ih-t-color">
# <div class="ih-pt-ic">
# <div class="ih-pt-img" style="width: 60px">
# <img alt="" src="https://bcciplayerimages.s3.ap-south-1.amazonaws.com/ipl/franchises/1645712208_GTroundbig.png"/>
# </div>
# <h2 class="ih-pt-cont">Gujarat Titans</h2>
# </div>
# </td>
# <td>₹15,00,000</td>
# <td>8</td>
# <td>23</td>
# </tr>
# <tr>
# <td class="ih-t-color">
# <div class="ih-pt-ic">
# <div class="ih-pt-img" style="width: 60px">
# <img alt="" src="https://bcciplayerimages.s3.ap-south-1.amazonaws.com/ipl/franchises/1644312095_KKRroundbig.png"/>
# </div>
# <h2 class="ih-pt-cont">Kolkata Knight Riders</h2>
# </div>
# </td>
# <td>₹45,00,000</td>
# <td>8</td>
# <td>25</td>
# </tr>
# <tr>
# <td class="ih-t-color">
# <div class="ih-pt-ic">
# <div class="ih-pt-img" style="width: 60px">
# <img alt="" src="https://bcciplayerimages.s3.ap-south-1.amazonaws.com/ipl/franchises/1644487352_lsgrounding.png"/>
# </div>
# <h2 class="ih-pt-cont">Lucknow Super Giants</h2>
# </div>
# </td>
# <td>₹0</td>
# <td>7</td>
# <td>21</td>
# </tr>
# <tr>
# <td class="ih-t-color">
# <div class="ih-pt-ic">
# <div class="ih-pt-img" style="width: 60px">
# <img alt="" src="https://bcciplayerimages.s3.ap-south-1.amazonaws.com/ipl/franchises/1644312227_MIroundbig.png"/>
# </div>
# <h2 class="ih-pt-cont">Mumbai Indians</h2>
# </div>
# </td>
# <td>₹10,00,000</td>
# <td>8</td>
# <td>25</td>
# </tr>
# <tr>
# <td class="ih-t-color">
# <div class="ih-pt-ic">
# <div class="ih-pt-img" style="width: 60px">
# <img alt="" src="https://bcciplayerimages.s3.ap-south-1.amazonaws.com/ipl/franchises/1644312239_PBKSroundbig.png"/>
# </div>
# <h2 class="ih-pt-cont">Punjab Kings</h2>
# </div>
# </td>
# <td>₹3,45,00,000</td>
# <td>7</td>
# <td>25</td>
# </tr>
# <tr>
# <td class="ih-t-color">
# <div class="ih-pt-ic">
# <div class="ih-pt-img" style="width: 60px">
# <img alt="" src="https://bcciplayerimages.s3.ap-south-1.amazonaws.com/ipl/franchises/1644312268_RRroundbig.png"/>
# </div>
# <h2 class="ih-pt-cont">Rajasthan Royals</h2>
# </div>
# </td>
# <td>₹95,00,000</td>
# <td>8</td>
# <td>24</td>
# </tr>
# <tr>
# <td class="ih-t-color">
# <div class="ih-pt-ic">
# <div class="ih-pt-img" style="width: 60px">
# <img alt="" src="https://bcciplayerimages.s3.ap-south-1.amazonaws.com/ipl/franchises/1644312253_RCBroundbig.png"/>
# </div>
# <h2 class="ih-pt-cont">Royal Challengers Bangalore</h2>
# </div>
# </td>
# <td>₹1,55,00,000</td>
# <td>8</td>
# <td>22</td>
# </tr>
# <tr>
# <td class="ih-t-color">
# <div class="ih-pt-ic">
# <div class="ih-pt-img" style="width: 60px">
# <img alt="" src="https://bcciplayerimages.s3.ap-south-1.amazonaws.com/ipl/franchises/1644312281_SRHroundbig.png"/>
# </div>
# <h2 class="ih-pt-cont">Sunrisers Hyderabad</h2>
# </div>
# </td>
# <td>₹10,00,000</td>
# <td>8</td>
# <td>23</td>
# </tr>
# </tbody>
# </table>

# %%
title=table.find_all("th",class_="skip-filter")
header=[]
for i in title:
    name=i.text
    header.append(name)

# %%
print(header)
# Out:
# ['TEAM', 'FUNDS REMAINING', 'OVERSEAS PLAYERS ', 'TOTAL PLAYERS']

# %%
df=pd.DataFrame(columns=header)
print(df)
# Out:
# Empty DataFrame
# Columns: [TEAM, FUNDS REMAINING, OVERSEAS PLAYERS , TOTAL PLAYERS]
# Index: []

# %%
rows=table.find_all("tr")
print(rows)
# Out:
# [<tr class="ih-pt-tbl" style="display:revert">
# <th class="skip-filter" style="width:25%;text-align: left;">TEAM</th>
# <th class="skip-filter" style="width:25%;">FUNDS REMAINING</th>
# <th class="skip-filter" style="width:25%;">OVERSEAS PLAYERS </th>
# <th class="skip-filter" style="width:25%;">TOTAL PLAYERS</th>
# </tr>, <tr>
# <td class="ih-t-color">
# <div class="ih-pt-ic">
# <div class="ih-pt-img" style="width: 60px">
# <img alt="" src="https://bcciplayerimages.s3.ap-south-1.amazonaws.com/ipl/franchises/1644311961_CSKroundbig.png"/>
# </div>
# <h2 class="ih-pt-cont">Chennai Super Kings</h2>
# </div>
# </td>
# <td>₹2,95,00,000</td>
# <td>8</td>
# <td>25</td>
# </tr>, <tr>
# <td class="ih-t-color">
# <div class="ih-pt-ic">
# <div class="ih-pt-img" style="width: 60px">
# <img alt="" src="https://bcciplayerimages.s3.ap-south-1.amazonaws.com/ipl/franchises/1644312373_DCroundbig.png"/>
# </div>
# <h2 class="ih-pt-cont">Delhi Capitals</h2>
# </div>
# </td>
# <td>₹10,00,000</td>
# <td>7</td>
# <td>24</td>
# </tr>, <tr>
# <td class="ih-t-color">
# <div class="ih-pt-ic">
# <div class="ih-pt-img" style="width: 60px">
# <img alt="" src="https://bcciplayerimages.s3.ap-south-1.amazonaws.com/ipl/franchises/1645712208_GTroundbig.png"/>
# </div>
# <h2 class="ih-pt-cont">Gujarat Titans</h2>
# </div>
# </td>
# <td>₹15,00,000</td>
# <td>8</td>
# <td>23</td>
# </tr>, <tr>
# <td class="ih-t-color">
# <div class="ih-pt-ic">
# <div class="ih-pt-img" style="width: 60px">
# <img alt="" src="https://bcciplayerimages.s3.ap-south-1.amazonaws.com/ipl/franchises/1644312095_KKRroundbig.png"/>
# </div>
# <h2 class="ih-pt-cont">Kolkata Knight Riders</h2>
# </div>
# </td>
# <td>₹45,00,000</td>
# <td>8</td>
# <td>25</td>
# </tr>, <tr>
# <td class="ih-t-color">
# <div class="ih-pt-ic">
# <div class="ih-pt-img" style="width: 60px">
# <img alt="" src="https://bcciplayerimages.s3.ap-south-1.amazonaws.com/ipl/franchises/1644487352_lsgrounding.png"/>
# </div>
# <h2 class="ih-pt-cont">Lucknow Super Giants</h2>
# </div>
# </td>
# <td>₹0</td>
# <td>7</td>
# <td>21</td>
# </tr>, <tr>
# <td class="ih-t-color">
# <div class="ih-pt-ic">
# <div class="ih-pt-img" style="width: 60px">
# <img alt="" src="https://bcciplayerimages.s3.ap-south-1.amazonaws.com/ipl/franchises/1644312227_MIroundbig.png"/>
# </div>
# <h2 class="ih-pt-cont">Mumbai Indians</h2>
# </div>
# </td>
# <td>₹10,00,000</td>
# <td>8</td>
# <td>25</td>
# </tr>, <tr>
# <td class="ih-t-color">
# <div class="ih-pt-ic">
# <div class="ih-pt-img" style="width: 60px">
# <img alt="" src="https://bcciplayerimages.s3.ap-south-1.amazonaws.com/ipl/franchises/1644312239_PBKSroundbig.png"/>
# </div>
# <h2 class="ih-pt-cont">Punjab Kings</h2>
# </div>
# </td>
# <td>₹3,45,00,000</td>
# <td>7</td>
# <td>25</td>
# </tr>, <tr>
# <td class="ih-t-color">
# <div class="ih-pt-ic">
# <div class="ih-pt-img" style="width: 60px">
# <img alt="" src="https://bcciplayerimages.s3.ap-south-1.amazonaws.com/ipl/franchises/1644312268_RRroundbig.png"/>
# </div>
# <h2 class="ih-pt-cont">Rajasthan Royals</h2>
# </div>
# </td>
# <td>₹95,00,000</td>
# <td>8</td>
# <td>24</td>
# </tr>, <tr>
# <td class="ih-t-color">
# <div class="ih-pt-ic">
# <div class="ih-pt-img" style="width: 60px">
# <img alt="" src="https://bcciplayerimages.s3.ap-south-1.amazonaws.com/ipl/franchises/1644312253_RCBroundbig.png"/>
# </div>
# <h2 class="ih-pt-cont">Royal Challengers Bangalore</h2>
# </div>
# </td>
# <td>₹1,55,00,000</td>
# <td>8</td>
# <td>22</td>
# </tr>, <tr>
# <td class="ih-t-color">
# <div class="ih-pt-ic">
# <div class="ih-pt-img" style="width: 60px">
# <img alt="" src="https://bcciplayerimages.s3.ap-south-1.amazonaws.com/ipl/franchises/1644312281_SRHroundbig.png"/>
# </div>
# <h2 class="ih-pt-cont">Sunrisers Hyderabad</h2>
# </div>
# </td>
# <td>₹10,00,000</td>
# <td>8</td>
# <td>23</td>
# </tr>]

# %%
for i in rows[1:]:
    data=i.find_all("td")
    row=[tr.text for tr in data]      #h=[]
                                      #for u in a:
                                      #   name=u.text
                                      #   h.append(name)
    l=len(df)
    df.loc[l]=row

# %%
print(df)
# Out:
#                                         TEAM FUNDS REMAINING  \
# 0          \n\n\n\n\nChennai Super Kings\n\n    ₹2,95,00,000
# 1               \n\n\n\n\nDelhi Capitals\n\n      ₹10,00,000
# 2               \n\n\n\n\nGujarat Titans\n\n      ₹15,00,000
# 3        \n\n\n\n\nKolkata Knight Riders\n\n      ₹45,00,000
# 4         \n\n\n\n\nLucknow Super Giants\n\n              ₹0
# 5               \n\n\n\n\nMumbai Indians\n\n      ₹10,00,000
# 6                 \n\n\n\n\nPunjab Kings\n\n    ₹3,45,00,000
# 7             \n\n\n\n\nRajasthan Royals\n\n      ₹95,00,000
# 8  \n\n\n\n\nRoyal Challengers Bangalore\n\n    ₹1,55,00,000
# 9          \n\n\n\n\nSunrisers Hyderabad\n\n      ₹10,00,000
#
#   OVERSEAS PLAYERS  TOTAL PLAYERS
# 0                 8            25
# 1                 7            24
# 2                 8            23
# 3                 8            25
# 4                 7            21
# 5                 8            25
# 6                 7            25
# 7                 8            24
# 8                 8            22
# 9                 8            23

# %%
for i in rows[1:]:
    first_td=i.find_all("td")[0].find("div",class_="ih-pt-ic").text.strip()
    data=i.find_all("td")[1:]
    row=[tr.text for tr in data]      #h=[]#for u in a:#   name=u.text#   h.append(name)
    row.insert(0,first_td)
    l=len(df)
    df.loc[l]=row

# %%
print(df)
# Out:
#                                          TEAM FUNDS REMAINING  \
# 0           \n\n\n\n\nChennai Super Kings\n\n    ₹2,95,00,000
# 1                \n\n\n\n\nDelhi Capitals\n\n      ₹10,00,000
# 2                \n\n\n\n\nGujarat Titans\n\n      ₹15,00,000
# 3         \n\n\n\n\nKolkata Knight Riders\n\n      ₹45,00,000
# 4          \n\n\n\n\nLucknow Super Giants\n\n              ₹0
# 5                \n\n\n\n\nMumbai Indians\n\n      ₹10,00,000
# 6                  \n\n\n\n\nPunjab Kings\n\n    ₹3,45,00,000
# 7              \n\n\n\n\nRajasthan Royals\n\n      ₹95,00,000
# 8   \n\n\n\n\nRoyal Challengers Bangalore\n\n    ₹1,55,00,000
# 9           \n\n\n\n\nSunrisers Hyderabad\n\n      ₹10,00,000
# 10                        Chennai Super Kings    ₹2,95,00,000
# 11                             Delhi Capitals      ₹10,00,000
# 12                             Gujarat Titans      ₹15,00,000
# 13                      Kolkata Knight Riders      ₹45,00,000
# 14                       Lucknow Super Giants              ₹0
# 15                             Mumbai Indians      ₹10,00,000
# 16                               Punjab Kings    ₹3,45,00,000
# 17                           Rajasthan Royals      ₹95,00,000
# 18                Royal Challengers Bangalore    ₹1,55,00,000
# 19                        Sunrisers Hyderabad      ₹10,00,000
# 20                        Chennai Super Kings    ₹2,95,00,000
# 21                             Delhi Capitals      ₹10,00,000
# 22                             Gujarat Titans      ₹15,00,000
# 23                      Kolkata Knight Riders      ₹45,00,000
# 24                       Lucknow Super Giants              ₹0
# 25                             Mumbai Indians      ₹10,00,000
# 26                               Punjab Kings    ₹3,45,00,000
# 27                           Rajasthan Royals      ₹95,00,000
# 28                Royal Challengers Bangalore    ₹1,55,00,000
# 29                        Sunrisers Hyderabad      ₹10,00,000
#
#    OVERSEAS PLAYERS  TOTAL PLAYERS
# 0                  8            25
# 1                  7            24
# 2                  8            23
# 3                  8            25
# 4                  7            21
# 5                  8            25
# 6                  7            25
# 7                  8            24
# 8                  8            22
# 9                  8            23
# 10                 8            25
# 11                 7            24
# 12                 8            23
# 13                 8            25
# 14                 7            21
# 15                 8            25
# 16                 7            25
# 17                 8            24
# 18                 8            22
# 19                 8            23
# 20                 8            25
# 21                 7            24
# 22                 8            23
# 23                 8            25
# 24                 7            21
# 25                 8            25
# 26                 7            25
# 27                 8            24
# 28                 8            22
# 29                 8            23

# %%
df.to_csv("ipl auction stats.csv")

# %%
a=table.find_all("td")
h=[]
for u in a:
    name=u.text
    h.append(name)

# %%
print(h)
# Out:
# ['\n\n\n\n\nChennai Super Kings\n\n', '₹2,95,00,000', '8', '25', '\n\n\n\n\nDelhi Capitals\n\n', '₹10,00,000', '7', '24', '\n\n\n\n\nGujarat Titans\n\n', '₹15,00,000', '8', '23', '\n\n\n\n\nKolkata Knight Riders\n\n', '₹45,00,000', '8', '25', '\n\n\n\n\nLucknow Super Giants\n\n', '₹0', '7', '21', '\n\n\n\n\nMumbai Indians\n\n', '₹10,00,000', '8', '25', '\n\n\n\n\nPunjab Kings\n\n', '₹3,45,00,000', '7', '25', '\n\n\n\n\nRajasthan Royals\n\n', '₹95,00,000', '8', '24', '\n\n\n\n\nRoyal Challengers Bangalore\n\n', '₹1,55,00,000', '8', '22', '\n\n\n\n\nSunrisers Hyderabad\n\n', '₹10,00,000', '8', '23']
